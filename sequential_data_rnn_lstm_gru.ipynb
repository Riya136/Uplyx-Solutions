# %% [markdown]
# # Sequential Data Analysis: RNN vs LSTM vs GRU
#
# This notebook compares RNN, LSTM, and GRU models for sentiment classification.

# %%
# !pip install -q numpy pandas matplotlib scikit-learn torch

# %%
from main import *

CSV_PATH = 'Womens Clothing E-Commerce Reviews.csv'
EPOCHS = 5
BATCH_SIZE = 64

# %% [markdown]
# ## Dataset Loading and Preprocessing
#
# The code cleans review text, tokenizes it, builds a vocabulary, converts words to indices, and pads batches.

# %%
set_seed()
device = get_device()
data = load_reviews(CSV_PATH)
data.head()

# %% [markdown]
# ## Train RNN, LSTM, and GRU
#
# Run the following command from the terminal for the complete comparison:
#
# ```bash
# python main.py --csv_path "Womens Clothing E-Commerce Reviews.csv" --epochs 5
# ```

# %% [markdown]
# ## Architectural Analysis
#
# - RNN uses a simple hidden state and may suffer from vanishing gradients.
# - LSTM uses a cell state and three gates to preserve long-term information.
# - GRU uses update and reset gates with fewer parameters than LSTM.
#
# The final comparison is saved in `outputs/rnn_lstm_gru_comparison.csv`.
